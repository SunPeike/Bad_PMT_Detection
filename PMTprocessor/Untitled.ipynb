# %%
import PMTprocessor

# %%
print(dir(PMTprocessor))
# Out:
# ['Counter', 'KMeans', 'StandardScaler', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'cluster', 'isfile', 'join', 'linear_model', 'listdir', 'matplotlib', 'metrics', 'np', 'os', 'overall_data_clean', 'pd', 'plt', 're', 'read_file', 'read_files', 'roc_auc_score', 'roc_curve', 'sklearn', 'sns', 'svm']

# %%
path = "/Users/peikesun/Documents/Year3/project/inputs"

# %%
PMTprocessor.overall_data_clean(path)
# Out:
#         qhs_main   qhs_neg  qhs_railed  qhs_second  qhs_third  IDK  high_occ  \
# 1       0.980193  0.000000    0.003865    0.014976   0.000966  0.0  0.000141
# 2       0.996224  0.000539    0.000539    0.003236   0.000000  0.0  0.000113
# 3       0.986268  0.000000    0.000808    0.012924   0.000808  0.0  0.000226
# 4       0.959541  0.000000    0.005394    0.029670   0.004720  0.0  0.000198
# 5       0.985529  0.000000    0.003808    0.009901   0.000000  0.0  0.000254
# ...          ...       ...         ...         ...        ...  ...       ...
# 145881  0.988479  0.000000    0.004608    0.006912   0.000000  0.0  0.000086
# 145884  0.989039  0.000000    0.000843    0.010118   0.000000  0.0  0.000286
# 145885  0.995595  0.000000    0.002643    0.001762   0.000000  0.0  0.000143
# 145886  0.978149  0.000000    0.001285    0.020566   0.000000  0.0  0.000172
# 145887  0.983871  0.001698    0.002547    0.011885   0.000000  0.0  0.000057
#
#          low_occ
# 1       0.000376
# ...
